# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(r"E:\moseq_raw_data\detectron2_testing_full\session_20200806170816\images\keypoints.tsv", sep='\t')

# %%
df
# Out:
#      Frame_Idx      Nose_X      Nose_Y    Nose_S  Left Ear_X  Left Ear_Y  \
# 0            0   92.221115  168.146423  0.333943   97.199661  155.162079
# 1            1   92.221115  168.146240  0.333981   97.199692  155.161880
# 2            2   93.100830  169.047455  0.416661   95.077698  159.137314
# 3            3   92.983658  172.829071  0.661898   97.956940  159.962784
# 4            4   91.947731  177.014496  0.648581   97.855202  163.111450
# ..         ...         ...         ...       ...         ...         ...
# 989        989  225.182922  102.945488  0.641907  222.216293   89.961754
# 990        990  226.036209  103.153694  1.144837  223.051300   91.279938
# 991        991  224.945343  102.296997  0.574977  222.968414   89.331604
# 992        992  223.080612  104.478271  0.569438  222.098145   89.620880
# 993        993  223.223633  104.147202  0.765148  222.232635   91.256516
#
#      Left Ear_S  Right Ear_X  Right Ear_Y  Right Ear_S  ...  Left Hip_S  \
# ...

# %%
for col in df.columns.values:
    if col.endswith('_S'):
        sns.histplot(data=df, x=col, legend=True)

# %%
sns.histplot(x=np.log(df['TailTip_S'] + 1))
# Out:
# <AxesSubplot:xlabel='TailTip_S', ylabel='Count'>

# %%
sns.__version__
# Out:
# '0.11.2'
