# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\moseq-extract-testing\test_2animal_full_timecourse\20MOS08-F\session_20200814133251\proc_5k\keypoints_00.tsv", sep='\t')
df
# Out:
#        Frame_Idx   Flip  Centroid_X  Centroid_Y       Angle  \
# 0              0   True   27.551040  145.600387  239.401997
# 1              1   True   29.351682  146.838940  250.046153
# 2              2   True   31.005829  149.252252  255.939502
# 3              3   True   31.933557  150.171971  266.641222
# 4              4   True   33.149888  149.572148  271.521545
# ...          ...    ...         ...         ...         ...
# 35994      35994  False  204.538951  185.582406  -10.724708
# 35995      35995  False  204.866258  185.831547  -12.730450
# 35996      35996  False  205.822556  185.883208  -15.138305
# 35997      35997  False  206.640842  186.049259  -11.834250
# 35998      35998  False  207.604406  186.714559  -12.733984
#
#        reference/Nose_x_px  reference/Nose_y_px  reference/Nose_score  \
# 0                15.611766           133.750458              0.991837
# 1                22.810688           132.416809              0.966608
# 2                28.874126           135.245636              0.776847
# 3                32.637539           137.060242              0.374138
# 4                34.769211           135.697296              0.701041
# ...                    ...                  ...                   ...
# 35994           215.966339           183.879074              0.543557
# 35995           217.444016           183.910370              0.862581
# 35996           218.730026           183.850235              0.654569
# 35997           221.039047           184.605637              0.745874
# 35998           222.538300           185.742615              0.243330
#
#        reference/Nose_x_mm  reference/Nose_y_mm  ...  reference/TailTip_score  \
# 0              -406.127527          -135.669330  ...                 0.562647
# 1              -393.965200          -137.981614  ...                 0.267673
# 2              -383.721232          -133.076984  ...                 0.389359
# 3              -377.363078          -129.930815  ...                 0.430134
# 4              -373.761693          -132.293894  ...                 0.301505
# ...                    ...                  ...  ...                      ...
# 35994           -67.635472           -48.756160  ...                 0.094591
# 35995           -65.138989           -48.701899  ...                 0.215937
# 35996           -62.966319           -48.806161  ...                 0.156058
# 35997           -59.065309           -47.496443  ...                 0.157752
# 35998           -56.532374           -45.525146  ...                 0.190760
#
#        reference/TailTip_x_mm  reference/TailTip_y_mm  reference/TailTip_z_mm  \
# 0                 -328.487446              -38.873379                     1.0
# 1                 -330.069592              -37.620012                     1.0
# 2                 -328.879135              -27.822816                     0.0
# 3                 -339.153477              -35.136982                     0.0
# 4                 -330.324026              -19.230467                     0.0
# ...                       ...                     ...                     ...
# 35994              -90.766960              -64.060806                     1.0
# 35995              -90.027948              -62.436027                     3.0
# 35996              -86.177336              -62.663943                     2.0
# 35997              -83.991493              -62.898791                     3.0
# 35998              -80.181096              -60.687011                     2.0
#
#        rotated/TailTip_x_px  rotated/TailTip_y_px  rotated/TailTip_score  \
# 0                -55.169742              6.894048               0.562647
# 1                -51.528286             14.568931               0.267673
# 2                -52.669761             18.075130               0.389359
# 3                -42.857094             20.845261               0.430134
# 4                -50.592565             28.683712               0.301505
# ...                     ...                   ...                    ...
# 35994             -0.265034            -10.767949               0.094591
# 35995              0.067806            -10.075297               0.215937
# 35996              1.815842             -9.894841               0.156058
# 35997              1.769785            -10.180622               0.157752
# 35998              3.054935             -9.271460               0.190760
#
#        rotated/TailTip_x_mm  rotated/TailTip_y_mm  rotated/TailTip_z_mm
# 0                -94.885789             10.654708                   1.0
# 1                -88.866638             23.956057                   1.0
# 2                -90.992311             30.034250                   0.0
# 3                -74.245200             35.109374                   0.0
# 4                -87.749742             48.520569                   0.0
# ...                     ...                   ...                   ...
# 35994             -0.360879            -18.650826                   1.0
# 35995              0.210723            -17.447538                   3.0
# 35996              3.183888            -17.146085                   2.0
# 35997              3.083895            -17.647964                   3.0
# 35998              5.256172            -16.084039                   2.0
#
# [35999 rows x 101 columns]

# %%
kpts = [
    'Nose',
    'Neck',
    'Left Ear',
    'Right Ear',
    'Left Hip',
    'Right Hip',
    'TailBase',
    'TailTip'
]
fig, axs = plt.subplots(len(kpts) // 2, 2, sharex=True, sharey=True, figsize=(20,20))
for kp, ax in zip(kpts, axs.flat):
    sns.histplot(x=df[f'reference/{kp}_score'], ax=ax)
    ax.set_title(f'Keypoint "{kp}" Score')
    ax.set_xlabel('Model Confidence Score')
