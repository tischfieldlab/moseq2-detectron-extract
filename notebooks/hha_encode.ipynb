# %%
from moseq2_detectron_extract.io.session import Session
import matplotlib.pyplot as plt
import numpy as np
import cv2

from moseq2_detectron_extract.proc.proc import prep_raw_frames, clean_frames, get_frame_features
from scipy import signal
import math
from mpl_toolkits.axes_grid1 import ImageGrid
import itertools

# %%
session = Session(r"E:\moseq_raw_data\detectron2_testing_full\session_20200915132521\depth.dat")
first_frame, bground_im, roi, true_depth = session.find_roi()

# %%
def plot_frames(frames, idxs, cols=5, fig_size=(20,20), vmin=0, vmax=100, features=None):
    cols = int(cols)
    rows = int(np.ceil(frames.shape[0] / cols))
    fig, axs = plt.subplots(rows, cols, sharex=True, sharey=True, figsize=fig_size)
    
    for i, ax in enumerate(axs.flat):
        ax.imshow(frames[i], vmin=vmin, vmax=vmax)
        if features is not None:
            feat = features[i]
            # draw the centroid as a point
            ax.scatter(feat['centroid'][0], feat['centroid'][1], c='r')
            # draw the orientation as an arrow
            r = 5
            dx = r * np.cos(feat['orientation'])
            dy = r * np.sin(feat['orientation'])
            ax.arrow(feat['centroid'][0], feat['centroid'][1], dx, dy, width=5)
        ax.set_title(idxs[i])
    fig.tight_layout()

def plot_tri_channel(frame, labels=None):
    if labels is None:
        labels = []

    fig = plt.figure(figsize=(24, 6))
    grid = ImageGrid(fig, 111, nrows_ncols=(1, 4), cbar_mode='each', axes_pad=0.4, share_all=True,)

    for i, (ax, cax, label) in enumerate(itertools.zip_longest(grid, grid.cbar_axes, labels, fillvalue="")):
        if i < 3:
            im = ax.imshow(frame[:, :, i])
            cax.colorbar(im)
        else:
            im = ax.imshow(frame)

        ax.set_title(label)

# %%
'''
This cell contains an implementation of HHA encoding of depth images
Taken from: https://github.com/charlesCXK/Depth2HHA-python
'''
def getCameraParam(colorOrZ='color'):
    '''
    getCameraParam: get the camera matrix
    colOrZ: color or depth
    '''
    if colorOrZ == 'color':
        fx_rgb = 5.1885790117450188e+02
        fy_rgb = 5.1946961112127485e+02
        cx_rgb = 3.2558244941119034e+02
        cy_rgb = 2.5373616633400465e+02
        C = np.array([[fx_rgb, 0, cx_rgb], [0, fy_rgb, cy_rgb], [0, 0, 1]])
    else:
        fx_d = 5.8262448167737955e+02
        fy_d = 5.8269103270988637e+02
        cx_d = 3.1304475870804731e+02
        cy_d = 2.3844389626620386e+02
        C = np.array([[fx_d, 0, cx_d], [0, fy_d, cy_d], [0, 0, 1]])
    return C

def filterItChopOff(f, r, sp):
    '''
    helper function
    '''
    f[np.isnan(f)] = 0
    H, W, d = f.shape
    B = np.ones([2 * r + 1, 2 * r + 1])     # 2r+1 * 2r+1 neighbourhood

    minSP = cv2.erode(sp, B, iterations=1)
    maxSP = cv2.dilate(sp, B, iterations=1)

    ind = np.where(np.logical_or(minSP != sp, maxSP != sp))

    spInd = np.reshape(range(np.size(sp)), sp.shape,'F')

    delta = np.zeros(f.shape)
    delta = np.reshape(delta, (H * W, d), 'F')
    f = np.reshape(f, (H * W, d),'F')

    # calculate delta

    I, J = np.unravel_index(ind, [H, W], 'C')
    for i in range(np.size(ind)):
        x = I[i]
        y = J[i]
        clipInd = spInd[max(0, x - r):min(H-1, x + r), max(0, y - r):min(W-1, y + r)]
        diffInd = clipInd[sp[clipInd] != sp[x, y]]
        delta[ind[i], :] = np.sum(f[diffInd, :], 1)
    delta = np.reshape(delta, (H, W, d), 'F')
    f = np.reshape(f, (H, W, d), 'F')
    fFilt = np.zeros([H, W, d])

    for i in range(f.shape[2]):
        #  fFilt(:,:,i) = filter2(B, f(:,:,i));
        tmp = cv2.filter2D(np.rot90(f[:, :, i], 2), -1, np.rot90(np.rot90(B, 2), 2))
        tmp = signal.convolve2d(np.rot90(f[:, :, i], 2), np.rot90(np.rot90(B, 2), 2), mode="same")
        fFilt[:, :, i] = np.rot90(tmp, 2)
    fFilt = fFilt - delta
    return fFilt


def mutiplyIt(AtA_1, Atb):
    '''
    helper function
    '''
    result = np.zeros([Atb.shape[0], Atb.shape[1], 3])
    result[:, :, 0] = np.multiply(AtA_1[:, :, 0], Atb[:, :, 0]) + np.multiply(AtA_1[:, :, 1],
                                                                              Atb[:, :, 1]) + np.multiply(
        AtA_1[:, :, 2], Atb[:, :, 2])
    result[:, :, 1] = np.multiply(AtA_1[:, :, 1], Atb[:, :, 0]) + np.multiply(AtA_1[:, :, 3],
                                                                              Atb[:, :, 1]) + np.multiply(
        AtA_1[:, :, 4], Atb[:, :, 2])
    result[:, :, 2] = np.multiply(AtA_1[:, :, 2], Atb[:, :, 0]) + np.multiply(AtA_1[:, :, 4],
                                                                              Atb[:, :, 1]) + np.multiply(
        AtA_1[:, :, 5], Atb[:, :, 2])
    return result


def invertIt(AtA):
    '''
    helper function
    '''
    AtA_1 = np.zeros([AtA.shape[0], AtA.shape[1], 6])
    AtA_1[:, :, 0] = np.multiply(AtA[:, :, 3], AtA[:, :, 5]) - np.multiply(AtA[:, :, 4], AtA[:, :, 4])
    AtA_1[:, :, 1] = -np.multiply(AtA[:, :, 1], AtA[:, :, 5]) + np.multiply(AtA[:, :, 2], AtA[:, :, 4])
    AtA_1[:, :, 2] = np.multiply(AtA[:, :, 1], AtA[:, :, 4]) - np.multiply(AtA[:, :, 2], AtA[:, :, 3])
    AtA_1[:, :, 3] = np.multiply(AtA[:, :, 0], AtA[:, :, 5]) - np.multiply(AtA[:, :, 2], AtA[:, :, 2])
    AtA_1[:, :, 4] = -np.multiply(AtA[:, :, 0], AtA[:, :, 4]) + np.multiply(AtA[:, :, 1], AtA[:, :, 2])
    AtA_1[:, :, 5] = np.multiply(AtA[:, :, 0], AtA[:, :, 3]) - np.multiply(AtA[:, :, 1], AtA[:, :, 1])

    x1 = np.multiply(AtA[:, :, 0], AtA_1[:, :, 0])
    x2 = np.multiply(AtA[:, :, 1], AtA_1[:, :, 1])
    x3 = np.multiply(AtA[:, :, 2], AtA_1[:, :, 2])

    detAta = x1 + x2 + x3
    return AtA_1, detAta


def getYDir(N, angleThresh, iter, y0):
    '''
    Compute the direction of gravity
    N: normal field
    iter: number of 'big' iterations
    '''
    y = y0
    for i in range(len(angleThresh)):
        thresh = np.pi * angleThresh[i] / 180   # convert it to radian measure
        y = getYDirHelper(N, y, thresh, iter[i])
    return y


def getYDirHelper(N, y0, thresh, num_iter):
    '''
    N: HxWx3 matrix with normal at each pixel.
    y0: the initial gravity direction
    thresh: in degrees the threshold for mapping to parallel to gravity and perpendicular to gravity
    iter: number of iterations to perform
    '''
    dim = N.shape[0] * N.shape[1]

    # change the third dimension to the first-order. (480, 680, 3) => (3, 480, 680)
    nn = np.swapaxes(np.swapaxes(N,0,2),1,2)
    nn = np.reshape(nn, (3, dim), 'F')

    # remove these whose number is NAN
    idx = np.where(np.invert(np.isnan(nn[0,:])))[0]
    nn = nn[:,idx]

    # Set it up as a optimization problem
    yDir = y0;
    for i in range(num_iter):
        sim0 = np.dot(yDir.T, nn)
        indF = abs(sim0) > np.cos(thresh)       # calculate 'floor' set.    |sin(theta)| < sin(thresh) ==> |cos(theta)| > cos(thresh)
        indW = abs(sim0) < np.sin(thresh)       # calculate 'wall' set.
        if(len(indF.shape) == 2):
            NF = nn[:, indF[0,:]]
            NW = nn[:, indW[0,:]]
        else:
            NF = nn[:, indF]
            NW = nn[:, indW]
        A = np.dot(NW, NW.T) - np.dot(NF, NF.T)
        b = np.zeros([3,1])
        c = NF.shape[1]
        w,v = np.linalg.eig(A)      # w:eigenvalues; v:eigenvectors
        min_ind = np.argmin(w)      # min index
        newYDir = v[:,min_ind]
        yDir = newYDir * np.sign(np.dot(yDir.T, newYDir))
    return yDir


def getRMatrix(yi, yf):
    '''
    getRMatrix: Generate a rotation matrix that
                if yf is a scalar, rotates about axis yi by yf degrees
                if yf is an axis, rotates yi to yf in the direction given by yi x yf
    Input: yi is an axis 3x1 vector
        yf could be a scalar of axis
    '''
    if (np.isscalar(yf)):
        ax = yi / np.linalg.norm(yi)        # norm(A) = max(svd(A))
        phi = yf
    else:
        yi = yi / np.linalg.norm(yi)
        yf = yf / np.linalg.norm(yf)
        ax = np.cross(yi.T, yf.T).T
        ax = ax / np.linalg.norm(ax)
        # find angle of rotation
        phi = np.degrees(np.arccos(np.dot(yi.T, yf)))

    if (abs(phi) > 0.1):
        phi = phi * (np.pi / 180)

        s_hat = np.array([[0, -ax[2], ax[1]],
                          [ax[2], 0, -ax[0]],
                          [-ax[1], ax[0], 0]])
        R = np.eye(3) + np.sin(phi) * s_hat + (1 - np.cos(phi)) * np.dot(s_hat, s_hat)      # dot???
    else:
        R = np.eye(3)
    return R


def rotatePC(pc, R):
    '''
    Calibration of gravity direction 
    '''
    if(np.array_equal(R, np.eye(3))):
        return pc
    else:
        R = R.astype(np.float64)
        dim = pc.shape[0] * pc.shape[1]
        pc = np.swapaxes(np.swapaxes(pc, 0, 2), 1, 2)
        res = np.reshape(pc, (3, dim), 'F')
        res = np.dot(R, res)
        res = np.reshape(res, pc.shape, 'F')
        res = np.swapaxes(np.swapaxes(res, 0, 1), 1, 2)
        return res


def processDepthImage(z, missingMask, C):
    '''
    z: depth image in 'centimetres'
    missingMask: a mask
    C: camera matrix
    '''
    yDirParam_angleThresh = np.array([45, 15]) # threshold to estimate the direction of the gravity
    yDirParam_iter = np.array([5, 5])
    yDirParam_y0 = np.array([0, 1, 0])

    normalParam_patchSize = np.array([3, 10])

    X, Y, Z = getPointCloudFromZ(z, C, 1)

    # with open('pd.txt', 'w', encoding='utf-8') as f:
    #     for i in range(X.shape[0]):
    #         for j in range(X.shape[1]):
    #             f.write('{} {} {}\n'.format(str(X[i,j]), str(Y[i,j]), str(Z[i,j])))

    # restore x-y-z position
    pc = np.zeros([z.shape[0], z.shape[1], 3])
    pc[:,:,0] = X
    pc[:,:,1] = Y
    pc[:,:,2] = Z

    N1, b1 = computeNormalsSquareSupport(z/100, missingMask, normalParam_patchSize[0],
    1, C, np.ones(z.shape))
    N2, b2 = computeNormalsSquareSupport(z/100, missingMask, normalParam_patchSize[1],
    1, C, np.ones(z.shape))

    N = N1

    # Compute the direction of gravity
    yDir = getYDir(N2, yDirParam_angleThresh, yDirParam_iter, yDirParam_y0)
    y0 = np.array([[0, 1, 0]]).T
    R = getRMatrix(y0, yDir)

    # rotate the pc and N
    NRot = rotatePC(N, R.T)

    pcRot = rotatePC(pc, R.T)
    h = -pcRot[:,:,1]
    yMin = np.percentile(h, 0)
    if (yMin > -90):
        yMin = -130
    h = h - yMin

    return pc, N, yDir, h,  pcRot, NRot


def getPointCloudFromZ(Z, C, s=1):
    '''
    getPointCloudFromZ: use depth image and camera matrix to get pointcloud
    Z is in 'centimetres'
    C: camera matrix
    s: is the factor by which Z has been upsampled
    '''
    h, w= Z.shape
    xx, yy = np.meshgrid(np.array(range(w))+1, np.array(range(h))+1)
    # color camera parameters
    cc_rgb = C[0:2,2] * s       # the first two lines of colomn-3, x0 and the y0
    fc_rgb = np.diag(C[0:2,0:2]) * s    # number on the diagonal line
    x3 = np.multiply((xx - cc_rgb[0]), Z) / fc_rgb[0]
    y3 = np.multiply((yy - cc_rgb[1]), Z) / fc_rgb[1]
    z3 = Z
    return x3, y3, z3


def computeNormalsSquareSupport(depthImage, missingMask, R, sc, cameraMatrix, superpixels):
    '''
    Clip out a 2R+1 x 2R+1 window at each point and estimate 
    the normal from points within this window. In case the window 
    straddles more than a single superpixel, only take points in the 
    same superpixel as the centre pixel. 
    
    Input:
        depthImage: in meters
        missingMask:  boolean mask of what data was missing
        R: radius of clipping
        sc: to upsample or not
        superpixels:  superpixel map to define bounadaries that should
                        not be straddled
    '''
    depthImage = depthImage*100     # convert to centi metres
    X, Y, Z = getPointCloudFromZ(depthImage, cameraMatrix, sc)
    Xf = X
    Yf = Y
    Zf = Z
    pc = np.zeros([depthImage.shape[0], depthImage.shape[1], 3])
    pc[:,:,0] = Xf
    pc[:,:,1] = Yf
    pc[:,:,2] = Zf
    XYZf = np.copy(pc)

    # find missing value
    ind = np.where(missingMask == 1)
    X[ind] = np.nan
    Y[ind] = np.nan
    Z[ind] = np.nan

    one_Z = np.expand_dims(1 / Z, axis=2)
    X_Z = np.divide(X, Z)
    Y_Z = np.divide(Y, Z)
    one = np.copy(Z)
    one[np.invert(np.isnan(one[:, :]))] = 1
    ZZ = np.multiply(Z, Z)
    X_ZZ = np.expand_dims(np.divide(X, ZZ), axis=2)
    Y_ZZ = np.expand_dims(np.divide(Y, ZZ), axis=2)

    X_Z_2 = np.expand_dims(np.multiply(X_Z, X_Z), axis=2)
    XY_Z = np.expand_dims(np.multiply(X_Z, Y_Z), axis=2)
    Y_Z_2 = np.expand_dims(np.multiply(Y_Z, Y_Z), axis=2)

    AtARaw = np.concatenate((X_Z_2, XY_Z, np.expand_dims(X_Z, axis=2), Y_Z_2,
                             np.expand_dims(Y_Z, axis=2), np.expand_dims(one, axis=2)), axis=2)

    AtbRaw = np.concatenate((X_ZZ, Y_ZZ, one_Z), axis=2)

    # with clipping
    AtA = filterItChopOff(np.concatenate((AtARaw, AtbRaw), axis=2), R, superpixels)
    Atb = AtA[:, :, AtARaw.shape[2]:]
    AtA = AtA[:, :, :AtARaw.shape[2]]

    AtA_1, detAtA = invertIt(AtA)
    N = mutiplyIt(AtA_1, Atb)

    divide_fac = np.sqrt(np.sum(np.multiply(N, N), axis=2))
    # with np.errstate(divide='ignore'):
    b = np.divide(-detAtA, divide_fac)
    for i in range(3):
        N[:, :, i] = np.divide(N[:, :, i], divide_fac)

    # Reorient the normals to point out from the scene.
    # with np.errstate(invalid='ignore'):
    SN = np.sign(N[:, :, 2])
    SN[SN == 0] = 1
    extend_SN = np.expand_dims(SN, axis=2)
    extend_SN = np.concatenate((extend_SN, extend_SN, extend_SN), axis=2)
    N = np.multiply(N, extend_SN)
    b = np.multiply(b, SN)
    sn = np.sign(np.sum(np.multiply(N, XYZf), axis=2))
    sn[np.isnan(sn)] = 1
    sn[sn == 0] = 1
    extend_sn = np.expand_dims(sn, axis=2)
    N = np.multiply(extend_sn, N)
    b = np.multiply(b, sn)
    return N, b


def getHHA(C, D, RD):
    '''
    C: Camera matrix
    D: Depth image, the unit of each element in it is "meter"
    RD: Raw depth image, the unit of each element in it is "meter"
    '''
    missingMask = (RD == 0);
    pc, N, yDir, h, pcRot, NRot = processDepthImage(D, missingMask, C);

    tmp = np.multiply(N, yDir)
    acosValue = np.minimum(1,np.maximum(-1,np.sum(tmp, axis=2)))
    # angle = np.array([math.degrees(math.acos(x)) for x in acosValue.flatten()])
    # JT - try this instead, faster?
    angle = np.rad2deg(np.arccos(acosValue.flatten()))
    angle = np.reshape(angle, h.shape)

    '''
    Must convert nan to 180 as the MATLAB program actually does. 
    Or we will get a HHA image whose border region is different
    with that of MATLAB program's output.
    '''
    angle[np.isnan(angle)] = 180


    pc[:,:,2] = np.maximum(pc[:,:,2], 100)
    I = np.zeros(pc.shape)

    # opencv-python save the picture in BGR order.
    I[:,:,2] = 31000/pc[:,:,2]
    I[:,:,1] = h
    I[:,:,0] = (angle + 128-90)

    # print(np.isnan(angle))

    '''
    np.uint8 seems to use 'floor', but in matlab, it seems to use 'round'.
    So I convert it to integer myself.
    '''
    I = np.rint(I)

    # np.uint8: 256->1, but in MATLAB, uint8: 256->255
    I[I>255] = 255
    HHA = I.astype(np.uint8)
    return HHA

# %%
frames_of_interest = range(18520, 18545)
frame_idxs, raw_frames = next(session.index(frames_of_interest))
raw_frames = prep_raw_frames(raw_frames, bground_im=None, roi=roi, vmin=None, vmax=None)

# %%
camera_matrix = getCameraParam('depth')
hha = getHHA(camera_matrix, raw_frames[0], raw_frames[0])
print(hha.shape)
plot_tri_channel(hha, labels=['angle', 'disparity', 'depth', 'merge'])
# Out:
# C:\Users\Josh\AppData\Local\Temp/ipykernel_4444/1179758126.py:326: RuntimeWarning: invalid value encountered in true_divide
#   b = np.divide(-detAtA, divide_fac)
# C:\Users\Josh\AppData\Local\Temp/ipykernel_4444/1179758126.py:328: RuntimeWarning: invalid value encountered in true_divide
#   N[:, :, i] = np.divide(N[:, :, i], divide_fac)
# C:\Users\Josh\AppData\Local\Temp/ipykernel_4444/1179758126.py:172: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   s_hat = np.array([[0, -ax[2], ax[1]],
# (245, 247, 3)

# %%
hha_frames = []
for rf in raw_frames:
    hha_frames.append(getHHA(camera_matrix, raw_frames[0], raw_frames[0]))

plot_frames(np.array(hha_frames), frame_idxs, vmin=None, vmax=None)
# Out:
# C:\Users\Josh\AppData\Local\Temp/ipykernel_4444/1179758126.py:326: RuntimeWarning: invalid value encountered in true_divide
#   b = np.divide(-detAtA, divide_fac)
# C:\Users\Josh\AppData\Local\Temp/ipykernel_4444/1179758126.py:328: RuntimeWarning: invalid value encountered in true_divide
#   N[:, :, i] = np.divide(N[:, :, i], divide_fac)
# C:\Users\Josh\AppData\Local\Temp/ipykernel_4444/1179758126.py:172: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   s_hat = np.array([[0, -ax[2], ax[1]],

# %%
# %%timeit -n 1000 -r 3
getHHA(camera_matrix, raw_frames[0], raw_frames[0])
# Out:
# C:\Users\Josh\AppData\Local\Temp/ipykernel_4444/1179758126.py:326: RuntimeWarning: invalid value encountered in true_divide
#   b = np.divide(-detAtA, divide_fac)
# C:\Users\Josh\AppData\Local\Temp/ipykernel_4444/1179758126.py:328: RuntimeWarning: invalid value encountered in true_divide
#   N[:, :, i] = np.divide(N[:, :, i], divide_fac)
# C:\Users\Josh\AppData\Local\Temp/ipykernel_4444/1179758126.py:172: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   s_hat = np.array([[0, -ax[2], ax[1]],
# 698 ms ± 4.23 ms per loop (mean ± std. dev. of 3 runs, 1000 loops each)

# %%
# %prun getHHA(camera_matrix, raw_frames[0], raw_frames[0])
# Out:
# C:\Users\Josh\AppData\Local\Temp/ipykernel_4444/1007947811.py:326: RuntimeWarning: invalid value encountered in true_divide
#   b = np.divide(-detAtA, divide_fac)
# C:\Users\Josh\AppData\Local\Temp/ipykernel_4444/1007947811.py:328: RuntimeWarning: invalid value encountered in true_divide
#   N[:, :, i] = np.divide(N[:, :, i], divide_fac)
# C:\Users\Josh\AppData\Local\Temp/ipykernel_4444/1007947811.py:172: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   s_hat = np.array([[0, -ax[2], ax[1]],
#          6095 function calls (5814 primitive calls) in 0.700 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        18    0.531    0.030    0.531    0.030 {built-in method scipy.signal.sigtools._convolve2d}
#        18    0.030    0.002    0.030    0.002 {filter2D}
#         2    0.022    0.011    0.615    0.308 1007947811.py:20(filterItChopOff)
#        46    0.017    0.000    0.017    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.014    0.014    0.699    0.699 1007947811.py:347(getHHA)
#         2    0.014    0.007    0.653    0.326 1007947811.py:266(computeNormalsSquareSupport)
#   568/287    0.013    0.000    0.051    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         2    0.012    0.006    0.020    0.010 1007947811.py:111(getYDirHelper)
#        62    0.012    0.000    0.012    0.000 {built-in method numpy.asarray}
#         2    0.007    0.004    0.007    0.004 1007947811.py:78(invertIt)
#         1    0.005    0.005    0.684    0.684 1007947811.py:198(processDepthImage)
#        30    0.003    0.000    0.003    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         2    0.003    0.002    0.003    0.002 1007947811.py:61(mutiplyIt)
#         2    0.002    0.001    0.002    0.001 {dilate}
#         2    0.002    0.001    0.002    0.001 {erode}
#         3    0.002    0.001    0.002    0.001 1007947811.py:248(getPointCloudFromZ)
#         1    0.001    0.001    0.700    0.700 <string>:1(<module>)
#        29    0.001    0.000    0.001    0.000 {built-in method numpy.array}
#       126    0.001    0.000    0.003    0.000 function_base.py:59(rot90)
#       252    0.001    0.000    0.002    0.000 function_base.py:150(flip)
#       282    0.001    0.000    0.001    0.000 numeric.py:1335(normalize_axis_tuple)
#        18    0.000    0.000    0.532    0.030 signaltools.py:1618(convolve2d)
#         1    0.000    0.000    0.020    0.020 1007947811.py:98(getYDir)
#        21    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#        25    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#        10    0.000    0.000    0.001    0.000 linalg.py:1187(eig)
#         6    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.004    0.002 1007947811.py:181(rotatePC)
#         1    0.000    0.000    0.000    0.000 {method 'partition' of 'numpy.ndarray' objects}
#        25    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        20    0.000    0.000    0.000    0.000 linalg.py:125(_realType)
#       252    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(flip)
#       126    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(rot90)
#       282    0.000    0.000    0.000    0.000 numeric.py:1385(<listcomp>)
#         3    0.000    0.000    0.000    0.000 linalg.py:2363(norm)
#         5    0.000    0.000    0.000    0.000 socket.py:480(send)
#        22    0.000    0.000    0.000    0.000 shape_base.py:512(expand_dims)
#        18    0.000    0.000    0.003    0.000 fromnumeric.py:69(_wrapreduction)
#       753    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         6    0.000    0.000    0.000    0.000 stride_tricks.py:339(_broadcast_to)
#         1    0.000    0.000    0.001    0.001 1007947811.py:150(getRMatrix)
#       285    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#       504    0.000    0.000    0.000    0.000 index_tricks.py:757(__getitem__)
#         2    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#        41    0.000    0.000    0.029    0.001 fromnumeric.py:51(_wrapfunc)
#         1    0.000    0.000    0.000    0.000 function_base.py:4018(_quantile_ureduce_func)
#        17    0.000    0.000    0.029    0.002 fromnumeric.py:198(reshape)
#         2    0.000    0.000    0.000    0.000 numeric.py:2385(array_equal)
#         1    0.000    0.000    0.700    0.700 {built-in method builtins.exec}
#        47    0.000    0.000    0.005    0.000 <__array_function__ internals>:2(dot)
#         5    0.000    0.000    0.003    0.001 fromnumeric.py:2123(sum)
#        10    0.000    0.000    0.000    0.000 linalg.py:205(_assert_finite)
#       167    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#       252    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         3    0.000    0.000    0.001    0.000 function_base.py:4248(meshgrid)
#         3    0.000    0.000    0.000    0.000 warnings.py:35(_formatwarnmsg_impl)
#        12    0.000    0.000    0.000    0.000 fromnumeric.py:2367(all)
#        17    0.000    0.000    0.029    0.002 <__array_function__ internals>:2(reshape)
#        10    0.000    0.000    0.000    0.000 linalg.py:135(_commonType)
#        10    0.000    0.000    0.000    0.000 {method 'argmin' of 'numpy.ndarray' objects}
#       260    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#        22    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(expand_dims)
#         1    0.000    0.000    0.000    0.000 numeric.py:1478(cross)
#         4    0.000    0.000    0.000    0.000 numeric.py:1398(moveaxis)
#        56    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#       252    0.000    0.000    0.000    0.000 function_base.py:146(_flip_dispatcher)
#         5    0.000    0.000    0.000    0.000 iostream.py:206(schedule)
#         4    0.000    0.000    0.000    0.000 numeric.py:149(ones)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:3169(size)
#         1    0.000    0.000    0.000    0.000 function_base.py:4007(_lerp)
#        18    0.000    0.000    0.000    0.000 signaltools.py:39(_valfrommode)
#       126    0.000    0.000    0.000    0.000 function_base.py:55(_rot90_dispatcher)
#         5    0.000    0.000    0.003    0.001 <__array_function__ internals>:2(sum)
#        35    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         9    0.000    0.000    0.007    0.001 <__array_function__ internals>:2(concatenate)
#         3    0.000    0.000    0.000    0.000 stride_tricks.py:478(broadcast_arrays)
#         5    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         3    0.000    0.000    0.000    0.000 stride_tricks.py:414(_broadcast_shape)
#        18    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#        22    0.000    0.000    0.000    0.000 shape_base.py:600(<listcomp>)
#         2    0.000    0.000    0.012    0.006 fromnumeric.py:38(_wrapit)
#        10    0.000    0.000    0.000    0.000 linalg.py:102(get_linalg_error_extobj)
#         3    0.000    0.000    0.000    0.000 iostream.py:500(write)
#        12    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#        12    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(all)
#        18    0.000    0.000    0.000    0.000 signaltools.py:55(_inputs_swap_needed)
#         6    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(where)
#         3    0.000    0.000    0.000    0.000 function_base.py:4360(<listcomp>)
#        18    0.000    0.000    0.000    0.000 signaltools.py:47(_bvalfromboundary)
#         3    0.000    0.000    0.000    0.000 twodim_base.py:161(eye)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#        10    0.000    0.000    0.000    0.000 linalg.py:107(_makearray)
#         1    0.000    0.000    0.001    0.001 function_base.py:3724(percentile)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:1202(argmin)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:1515(diagonal)
#        10    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(eig)
#         3    0.000    0.000    0.000    0.000 linecache.py:15(getline)
#        10    0.000    0.000    0.000    0.000 linalg.py:193(_assert_stacked_2d)
#         3    0.000    0.000    0.000    0.000 warnings.py:403(__init__)
#        12    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(swapaxes)
#         3    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(meshgrid)
#         3    0.000    0.000    0.000    0.000 warnings.py:20(_showwarnmsg_impl)
#        52    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         3    0.000    0.000    0.000    0.000 twodim_base.py:234(diag)
#         5    0.000    0.000    0.000    0.000 threading.py:1071(is_alive)
#         1    0.000    0.000    0.000    0.000 function_base.py:3995(_quantile_is_valid)
#         3    0.000    0.000    0.000    0.000 iostream.py:418(_is_master_process)
#        33    0.000    0.000    0.000    0.000 linalg.py:112(isComplexType)
#        12    0.000    0.000    0.000    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(argmin)
#         3    0.000    0.000    0.000    0.000 {method 'diagonal' of 'numpy.ndarray' objects}
#        12    0.000    0.000    0.000    0.000 fromnumeric.py:550(swapaxes)
#        14    0.000    0.000    0.000    0.000 _methods.py:60(_all)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(size)
#         1    0.000    0.000    0.000    0.000 numeric.py:1858(isscalar)
#        18    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diag)
#         4    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(copy)
#         3    0.000    0.000    0.000    0.000 function_base.py:4373(<listcomp>)
#         5    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        47    0.000    0.000    0.000    0.000 multiarray.py:736(dot)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(unravel_index)
#         3    0.000    0.000    0.000    0.000 linecache.py:37(getlines)
#        21    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 stride_tricks.py:544(<listcomp>)
#         5    0.000    0.000    0.000    0.000 iostream.py:96(_event_pipe)
#         1    0.000    0.000    0.000    0.000 function_base.py:3513(_ureduce)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diagonal)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(broadcast_arrays)
#         6    0.000    0.000    0.000    0.000 function_base.py:244(iterable)
#        10    0.000    0.000    0.000    0.000 linalg.py:199(_assert_stacked_square)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:358(issubdtype)
#         5    0.000    0.000    0.000    0.000 threading.py:1017(_wait_for_tstate_lock)
#         4    0.000    0.000    0.000    0.000 numerictypes.py:284(issubclass_)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         6    0.000    0.000    0.000    0.000 stride_tricks.py:540(<genexpr>)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(moveaxis)
#         2    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.generic' objects}
#         6    0.000    0.000    0.000    0.000 stride_tricks.py:25(_maybe_view_as_subclass)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#        22    0.000    0.000    0.000    0.000 shape_base.py:508(_expand_dims_dispatcher)
#         4    0.000    0.000    0.001    0.000 function_base.py:726(copy)
#         3    0.000    0.000    0.000    0.000 stride_tricks.py:536(<listcomp>)
#         3    0.000    0.000    0.000    0.000 warnings.py:96(_showwarnmsg)
#        28    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#        44    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 iostream.py:437(_schedule_flush)
#        17    0.000    0.000    0.000    0.000 fromnumeric.py:193(_reshape_dispatcher)
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         3    0.000    0.000    0.000    0.000 warnings.py:117(_formatwarnmsg)
#         1    0.000    0.000    0.000    0.000 function_base.py:3983(_quantile_unchecked)
#        18    0.000    0.000    0.000    0.000 stride_tricks.py:344(<genexpr>)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(norm)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:93(take)
#         5    0.000    0.000    0.000    0.000 fromnumeric.py:2118(_sum_dispatcher)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(take)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(array_equal)
#         1    0.000    0.000    0.001    0.001 <__array_function__ internals>:2(percentile)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2268(any)
#         4    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         5    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 multiarray.py:341(where)
#         1    0.000    0.000    0.000    0.000 abc.py:96(__instancecheck__)
#        12    0.000    0.000    0.000    0.000 fromnumeric.py:546(_swapaxes_dispatcher)
#        12    0.000    0.000    0.000    0.000 fromnumeric.py:2362(_all_dispatcher)
#         3    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.generic' objects}
#         9    0.000    0.000    0.000    0.000 multiarray.py:148(concatenate)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:1198(_argmin_dispatcher)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(cross)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(any)
#        10    0.000    0.000    0.000    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        10    0.000    0.000    0.000    0.000 linalg.py:472(_unary_dispatcher)
#         4    0.000    0.000    0.000    0.000 multiarray.py:1071(copyto)
#         3    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 numeric.py:1460(<listcomp>)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:1511(_diagonal_dispatcher)
#         4    0.000    0.000    0.000    0.000 function_base.py:722(_copy_dispatcher)
#         5    0.000    0.000    0.000    0.000 threading.py:513(is_set)
#         4    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 twodim_base.py:230(_diag_dispatcher)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:3165(_size_dispatcher)
#         1    0.000    0.000    0.000    0.000 _methods.py:54(_any)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.promote_types}
#         3    0.000    0.000    0.000    0.000 function_base.py:4243(_meshgrid_dispatcher)
#         3    0.000    0.000    0.000    0.000 stride_tricks.py:474(_broadcast_arrays_dispatcher)
#         3    0.000    0.000    0.000    0.000 linalg.py:2359(_norm_dispatcher)
#         4    0.000    0.000    0.000    0.000 numeric.py:1394(_moveaxis_dispatcher)
#         2    0.000    0.000    0.000    0.000 multiarray.py:1021(unravel_index)
#         2    0.000    0.000    0.000    0.000 numeric.py:2381(_array_equal_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:3719(_percentile_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:89(_take_dispatcher)
#         1    0.000    0.000    0.000    0.000 numeric.py:1474(_cross_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2263(_any_dispatcher)

# %%
cleaned_frames = clean_frames(raw_frames, iters_tail=3, prefilter_time=(3,))
features, masks = get_frame_features(cleaned_frames, progress_bar=False, use_cc=True, frame_threshold=3)

# %%
plot_frames(cleaned_frames, frame_idxs, vmin=None, vmax=None)
